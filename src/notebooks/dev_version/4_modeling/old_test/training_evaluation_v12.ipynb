# %% [markdown]
# error analysis + log more features 2

# %%
import sys
sys.path.append('../../')

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from modules import machine_learning_utils as mlu

pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %% [markdown]
# # 1.0 Data retrieval

# %%
df = pd.read_pickle("../../data_lake/output/train_eng.pkl")
val = pd.read_pickle("../../data_lake/output/val_eng.pkl")

# %%
# df = df.drop(columns=['addr1', 'addr2','id_21', 'id_22', 'id_23', 'id_24', 'id_25',
#        'id_26', 'id_27', 'id_28', 'id_29','id_35', 'id_36', 'id_37', 'id_38','id_34','M4','id_32','R_emaildomain','id_30','id_33','num_transaction_per_time'])

# %%
df.sample(3)
# Out:
#       isFraud  TransactionAmt ProductCD card1  card2  card3       card4  \
# 83057       1          17.643         C  8755  500.0  185.0  mastercard
# 56901       0          50.000         H  9803  583.0  150.0        visa
# 32651       0         250.000         R  9803  583.0  150.0        visa
#
#        card5   card6  addr1 addr2 P_emaildomain R_emaildomain   M4 id_21  \
# 83057  224.0  credit    NaN   NaN     gmail.com     gmail.com   M2   NaN
# 56901  226.0  credit  299.0  87.0     gmail.com   hotmail.com  NaN   NaN
# 32651  226.0  credit  299.0  87.0       mac.com       mac.com  NaN   NaN
#
#       id_22 id_23 id_24 id_25 id_26 id_27  id_28     id_29             id_30  \
# 83057   NaN   NaN   NaN   NaN   NaN   NaN  Found     Found               NaN
# 56901   NaN   NaN   NaN   NaN   NaN   NaN    New  NotFound  Mac_OS_X_10_12_6
# 32651   NaN   NaN   NaN   NaN   NaN   NaN  Found  NotFound        iOS_11_2_0
#
#       id_32      id_33           id_34 id_35 id_36 id_37 id_38 DeviceType  \
# 83057   NaN        NaN             NaN     F     F     T     F    desktop
# 56901  24.0   1440x900  match_status:2     T     F     F     T    desktop
# 32651  32.0  2048x1536  match_status:2     T     F     T     F     mobile
#
#        max_c  max_d  num_transaction_per_time  multi_transaction_per_time  \
# 83057    6.0   22.0                         1                           0
# 56901    2.0    0.0                         1                           0
# 32651    1.0    0.0                         1                           0
#
#       browser_enc device_info_v4
# 83057      chrome        windows
# 56901      safari            ios
# 32651      chrome            ios

# %%
df = df.drop(columns=['id_21', 'id_22', 'id_23', 'id_24', 'id_25',
       'id_26', 'id_27'])

# %%
val = val.drop(columns=['id_21', 'id_22', 'id_23', 'id_24', 'id_25',
       'id_26', 'id_27'])

# %% [markdown]
# # 2.0 Training baseline

# %%
for i in df:
    if df[i].dtypes == 'object':
        df[i] = df[i].astype(str)

# %%
X_train = df.drop(columns='isFraud')
y_train = df['isFraud'].astype(float)

# %%
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X_train.select_dtypes(include=['object', 'bool']).columns

# %%
# parameters = {'model__max_depth':[3,6,10],
#               'model__n_estimators':[100,400,800],
#               'model__learning_rate':[0.05,0.01,0.1],
#               'model__min_samples_leaf':[1,3],
#               'model__min_samples_split':[2,4,6]}

# %%
# {'model__learning_rate': 0.5, 'model__max_depth': 6, 'model__min_samples_leaf': 3, 'model__n_estimators': 600}

# %%
parameters = {'model__max_depth':[6,8],'model__n_estimators':[500,800],'model__learning_rate':[0.5,0.1],'model__min_samples_leaf':[3,5]}

# %%
model = mlu.model_training(X_train,y_train,numerical_cols,categorical_cols,parameters)
# Out:
# GridSearchCV results...
# Mean Train Scores:
# [0.93310103 0.93310103 0.94011801 0.94011801 0.95726944 0.95726944
#  0.94763524 0.94763524 0.92114105 0.92898988 0.91740395 0.91906508
#  0.94497747 0.94493594 0.94223652 0.94223652]
#
# Mean CV Scores:
# [0.85262256 0.85262256 0.85175093 0.85175093 0.85386808 0.85386808
#  0.85486409 0.85486409 0.85635936 0.85885064 0.85486441 0.85511353
#  0.86084398 0.8610931  0.85835263 0.85835263]
#
# Best Parameters:
# {'model__learning_rate': 0.1, 'model__max_depth': 8, 'model__min_samples_leaf': 3, 'model__n_estimators': 800}

# %% [markdown]
# # 3.0 Evaluation baseline

# %%
for i in val:
    if val[i].dtypes == 'object':
        val[i] = val[i].astype(str)

# %%
X_val = val.drop(columns='isFraud')
y_val = val['isFraud'].astype(float)

# %%
m = mlu.model_calibration(model,X_val,y_val)

# %%
mlu.model_evaluation(m.base_estimator, X_val, y_val)
# Out:
# Test results...
# Model Test Recall: 0.8607594936708861
# --------------------------------------------------
# Model Test Confusion Matrix
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.93     19976
#          1.0       0.36      0.86      0.51      1659
#
#     accuracy                           0.87     21635
#    macro avg       0.67      0.87      0.72     21635
# weighted avg       0.94      0.87      0.89     21635
#
# ProductCD: 0.30009288764699804
# TransactionAmt: 0.08920320516519875
# card1: 0.0873842667099574
# card6: 0.022168719512367083
# addr1: 0.003443556793495175
# addr2: 0.0029731324603849505
# card5: 0.0024896574876844806
# id_36: 0.00045500637398979393
# card3: 0.00021033647982999585
# card2: 0.00020406024236337462
# multi_transaction_per_time: 0.00010363811583686244
# card4: 9.596556027517888e-05
# id_28: 4.358385435996547e-05
# id_33: 3.465822388359124e-05
# id_29: 2.6094900724476228e-05
# num_transaction_per_time: 0.0
# max_d: 0.0
# max_c: 0.0
# id_38: 0.0
# id_37: 0.0
# id_35: 0.0
# id_34: 0.0
# id_32: 0.0
# id_30: 0.0
# device_info_v4: 0.0
# browser_enc: 0.0
# R_emaildomain: 0.0
# P_emaildomain: 0.0
# M4: 0.0
# DeviceType: 0.0
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical_preprocessor',
#                                                   Pipeline(steps=[('imputer',
#                                                                    IterativeImputer(add_indicator=True,
#                                                                                     estimator=ExtraTreesRegressor(n_estimators=5,
#                                                                                                                   random_state=1),
#                                                                                     random_state=1)),
#                                                                   ('scaler',
#                                                                    FunctionTransformer(func=<function log_transform at 0x7f64dc1939d0>))]),
#                                                   Index(['TransactionAmt', 'max_c', 'max_d',...
#        'addr1', 'addr2', 'P_emaildomain', 'R_emaildomain', 'M4', 'id_28',
#        'id_29', 'id_30', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37',
#        'id_38', 'DeviceType', 'browser_enc', 'device_info_v4'],
#       dtype='object'))])),
#                 ('model',
#                  GradientBoostingClassifier(max_depth=8, max_features='auto',
#                                             min_samples_leaf=3,
#                                             n_estimators=800,
#                                             n_iter_no_change=25, random_state=0,
#                                             warm_start=True))])

# %% [markdown]
# # 4.0 Error analysis

# %%
val.insert(0,'probability_score','')
val['probability_score'] = model.predict_proba(X_val)[:,1]

# %%
val.sample(2)
# Out:
#        probability_score isFraud  TransactionAmt ProductCD  card1  card2  \
# 55958           0.069647       0          27.136         C  13832  375.0
# 22195           0.007953       0          25.000         R  16227  543.0
#
#        card3       card4  card5  card6  P_emaildomain  R_emaildomain  \
# 55958  185.0  mastercard  224.0  debit    hotmail.com    hotmail.com
# 22195  150.0  mastercard  224.0  debit  anonymous.com  anonymous.com
#
#             id_30      id_33 DeviceType  max_c  max_d  \
# 55958         nan        nan    desktop    1.0    0.0
# 22195  iOS_11_1_2  2048x1536     mobile    1.0    0.0
#
#        num_transaction_per_time  multi_transaction_per_time browser_enc  \
# 55958                         1                           0      chrome
# 22195                         1                           0      safari
#
#       device_info_v4
# 55958        windows
# 22195            ios

# %%
er = val[(val['probability_score']<0.05) & (val['isFraud']=='1')]

# %%
er.shape
# Out:
# (28, 21)

# %%
er.sample(5)
# Out:
#         probability_score isFraud  TransactionAmt ProductCD  card1  card2  \
# 83518            0.034218       1          50.000         R  12808  555.0
# 121697           0.045263       1          47.708         C  15257  375.0
# 39930            0.034092       1          40.000         H   6019  583.0
# 57522            0.015318       1         100.000         R   8528  215.0
# 10135            0.031790       1          50.000         S  12883  404.0
#
#         card3       card4  card5   card6 P_emaildomain R_emaildomain  \
# 83518   150.0        visa  226.0   debit     gmail.com     gmail.com
# 121697  185.0  mastercard  224.0   debit   hotmail.com   hotmail.com
# 39930   150.0        visa  226.0  credit     gmail.com     gmail.com
# 57522   150.0        visa  226.0   debit     gmail.com       aol.com
# 10135   150.0        visa  226.0  credit           nan     gmail.com
#
#                    id_30      id_33 DeviceType  max_c    max_d  \
# 83518         iOS_11_2_2   1334x750     mobile    1.0    0.000
# 121697               nan        nan    desktop    1.0  547.000
# 39930      Android_5_1_1    960x540     mobile    1.0    0.000
# 57522   Mac_OS_X_10_13_1  2880x1800    desktop    1.0    0.000
# 10135         Windows_10   1366x768    desktop    1.0  229.875
#
#         num_transaction_per_time  multi_transaction_per_time browser_enc  \
# 83518                          1                           0      safari
# 121697                         1                           0      chrome
# 39930                          1                           0      chrome
# 57522                          1                           0      safari
# 10135                          1                           0      chrome
#
#        device_info_v4
# 83518             ios
# 121697          other
# 39930         samsung
# 57522             ios
# 10135         windows

# %%
er['probability_score'].hist()
# Out:
# <AxesSubplot:>

# %%
for i in er:
    print(i)
    print(er[i].value_counts(normalize=True).head(5))
# Out:
# probability_score
# 0.435288    0.008439
# 0.485538    0.008439
# 0.235251    0.008439
# 0.035126    0.004219
# 0.398104    0.004219
# Name: probability_score, dtype: float64
# isFraud
# 1    1.0
# Name: isFraud, dtype: float64
# TransactionAmt
# 100.0    0.075949
# 150.0    0.059072
# 50.0     0.046414
# 200.0    0.021097
# 175.0    0.021097
# Name: TransactionAmt, dtype: float64
# ProductCD
# C    0.658228
# R    0.156118
# H    0.139241
# S    0.046414
# Name: ProductCD, dtype: float64
# card1
# 15885    0.147679
# 5812     0.054852
# 3154     0.046414
# 4461     0.029536
# 13832    0.025316
# Name: card1, dtype: float64
# card2
# 545.0    0.206751
# 408.0    0.105485
# 555.0    0.075949
# 375.0    0.067511
# 514.0    0.037975
# Name: card2, dtype: float64
# card3
# 185.0    0.573840
# 150.0    0.367089
# 119.0    0.016878
# 106.0    0.008439
# 147.0    0.008439
# Name: card3, dtype: float64
# card4
# visa                0.594937
# mastercard          0.362869
# discover            0.021097
# american express    0.021097
# Name: card4, dtype: float64
# card5
# 226.0    0.278481
# 224.0    0.261603
# 138.0    0.206751
# 102.0    0.071730
# 137.0    0.063291
# Name: card5, dtype: float64
# card6
# debit     0.556962
# credit    0.443038
# Name: card6, dtype: float64
# P_emaildomain
# gmail.com        0.379747
# hotmail.com      0.257384
# anonymous.com    0.097046
# nan              0.088608
# yahoo.com        0.054852
# Name: P_emaildomain, dtype: float64
# R_emaildomain
# gmail.com        0.413502
# hotmail.com      0.261603
# anonymous.com    0.088608
# nan              0.063291
# yahoo.com        0.054852
# Name: R_emaildomain, dtype: float64
# id_30
# nan           0.683544
# Windows_10    0.097046
# Windows_7     0.046414
# iOS_11_3_0    0.029536
# iOS_11_2_1    0.021097
# Name: id_30, dtype: float64
# id_33
# nan          0.696203
# 1366x768     0.046414
# 1920x1080    0.037975
# 2208x1242    0.033755
# 1440x900     0.033755
# Name: id_33, dtype: float64
# DeviceType
# desktop    0.544304
# mobile     0.438819
# nan        0.016878
# Name: DeviceType, dtype: float64
# max_c
# 1.0    0.599156
# 2.0    0.160338
# 3.0    0.088608
# 4.0    0.042194
# 5.0    0.025316
# Name: max_c, dtype: float64
# max_d
# 0.000000      0.409283
# 2.000000      0.016878
# 495.208344    0.008439
# 23.000000     0.008439
# 0.916666      0.008439
# Name: max_d, dtype: float64
# num_transaction_per_time
# 1    0.983122
# 2    0.016878
# Name: num_transaction_per_time, dtype: float64
# multi_transaction_per_time
# 0    0.983122
# 1    0.016878
# Name: multi_transaction_per_time, dtype: float64
# browser_enc
# chrome     0.565401
# safari     0.244726
# firefox    0.088608
# edge       0.033755
# other      0.029536
# Name: browser_enc, dtype: float64
# device_info_v4
# other      0.362869
# windows    0.316456
# ios        0.147679
# samsung    0.092827
# lg         0.033755
# Name: device_info_v4, dtype: float64

# %% [markdown]
# # 4.0 Model Output

# %%
with open('../../data_lake/output/trained_model_v1.pkl','wb') as file:
    pickle.dump(m.base_estimator, file)
